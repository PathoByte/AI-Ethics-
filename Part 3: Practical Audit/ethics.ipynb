# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('CHART1_NJ.csv')

# Display basic information about the dataset
print("Dataset shape:", df.shape)
print("\nFirst few rows:")
print(df.head())
print("\nColumn names:", df.columns.tolist())
print("\nBasic statistics:")
print(df.describe())
# Out:
# Dataset shape: (12190, 18)
#
# First few rows:
#                   Clean Plaintiff Plaintiff Type   1996   1997   1998   1999  \
# 0                           Other          Other  65388  62181  59402  53654
# 1            Encore Capital Group     Debt Buyer      7     21     11     36
# 2                     Capital One     Major Bank      3      6      2     52
# 3  New Century Financial Services     Debt Buyer     77    331   5613   3090
# 4     Sherman Financial Group LLC     Debt Buyer      6     57     75     28
#
#     2000   2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# 0  54680  53571  53761  53221  50714  45480  48067  50101  52247  48197
# 1    176    700    982    901   3691   5318  13143  14147  28204  21049
# 2   1287   7732  18217  24090  15341  15129  19733  31198  38481  41299
# 3   8616  29323  17288  51698  22700  25259  18798  18761  33816  35061
# 4     13     37    103   1583   1970   2284   4269  10807  10072   6214
#
#     2010   2011
# ...
